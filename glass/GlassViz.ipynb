# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
glass = pd.read_csv("./glass.csv")

# %%
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
sns.set(style="white", color_codes=True)

# %%
glass.plot(kind="scatter", x="RI", y="Na")

# %%
glass.plot(kind="scatter", x="RI", y="Mg")

# %%
glass.plot(kind="scatter", x="RI", y="Al")

# %%
glass.plot(kind="scatter", x="RI", y="Si")

# %%
glass.plot(kind="scatter", x="RI", y="K")

# %%
glass.plot(kind="scatter", x="RI", y="Ca")

# %%
glass.plot(kind="scatter", x="RI", y="Ba")

# %%
glass.plot(kind="scatter", x="RI", y="Fe")

# %%
sns.boxplot(x="Type", y="RI", data=glass)

# %%
sns.violinplot(x="Type", y="RI", data=glass, size=6)

# %%
sns.FacetGrid(glass, hue="Type", size=6) \
    .map(sns.kdeplot, "RI") \
    .add_legend()

# %%
sns.pairplot(glass, hue="Type", size=3)

# %%
glass.boxplot(by="Type", figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f974bf14c50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f974b90bbd0>]], dtype=object)

# %%
from pandas.tools.plotting import andrews_curves
andrews_curves(glass, "Type")

# %%
from pandas.tools.plotting import parallel_coordinates
parallel_coordinates(glass, "Type")

# %%
from pandas.tools.plotting import radviz
radviz(glass, "Type")
